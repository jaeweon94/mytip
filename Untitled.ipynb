# %%
Content.objects.all()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\django\db\backends\utils.py in execute(self, sql, params)
#      63             else:
# ---> 64                 return self.cursor.execute(sql, params)
#      65
#
# C:\ProgramData\Anaconda3\lib\site-packages\django\db\backends\sqlite3\base.py in execute(self, query, params)
#     336         query = self.convert_query(query)
# --> 337         return Database.Cursor.execute(self, query, params)
#     338
#
# OperationalError: no such table: content_content
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     670                 type_pprinters=self.type_printers,
# ...
